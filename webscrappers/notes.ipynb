# %% [markdown]
# ## Notes for ecommerce website - youtuebe
#
# - This this prctice notes i write to imporove my node.js skills

# %% [markdown]
# ## The config folder need to have the files of database connection
#
# - Like Mongodb or mysql or any database
# - The files must be sepreated on basis of the structure

# %% [markdown]
# ### We creating a user details in mongoose db
# - Where the userController stores the schema of the user and authRoute stores the where the routes has to be redirect saved
# - we use authroutes to autenticate the users in mongodb

# %% [markdown]
# ### Exception handaling while 404
# - We are creating 404 pages for not found pages where it returns to the static page of the 404
# - We use the middleware for errorhandalin and importing to the index js and using it in the express

# %%
## This is some random data need to add in product page for testing the headers 

import requests
from faker import Faker
import random
import string
fake = Faker()

# Generate random data
# for i in range(500):


def fakeProduct_data():
    data = {
        "productName": fake.company(),
        "discription": fake.sentence(),
        "productid": fake.random_number(digits=4),
        "images": [fake.image_url() for _ in range(2)],
        "price": fake.random_number(digits=4),
        "quantity": fake.random_number(digits=2),
        "oldPrice": fake.random_number(digits=4),
        "newPrice": fake.random_number(digits=4),
        "discount": fake.random_number(digits=3),
        'max_purchase_limit': random.randint(1,5),
        "category": random.choice(['electronics','beauty','smartphones','clothes']),
        "tags": [fake.word() for _ in range(3)],
        "rating": fake.pyfloat(left_digits=1, right_digits=1, positive=True),
    }
    return data


def fake_coupon_data(categories):
    coupon_code = ''.join(random.choices(string.ascii_uppercase + string.digits, k=6))  # Random 6-digit alphanumeric code
    coupon = {"couponcode":{
        'coupon': coupon_code,
        'maxdiscount': random.randint(10, 50),  # Random max discount percentage
        'categories': random.sample(categories, random.randint(1, len(categories))),  # Random categories
        'minprice': random.randint(500, 1500),  # Random min price
        'maxprice': random.randint(2000, 10000)  # Random max price
    }}
    return coupon['couponcode']['coupon'],coupon

def endpoint(endpoint_url, data):
    # API endpoint and authorization token
    url = f"http://localhost:4000/api/{endpoint_url}"
    headers = {
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjY2MDc5MzIyOWJlM2ZjNzc4ZTVkYjU0YyIsImlhdCI6MTcxMTg1NTc3MiwiZXhwIjoxNzEyMjg3NzcyfQ.KTIToaIM2Lc9Rv5NFcnS71Fb_3Cm9q15FyPz0CTls8g",
        "Content-Type": "application/json"
    }

    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        print("Data added successfully!")
    else:
        print("Error:", response.text)

# %%
coupons = {}
for i in range(100):
    (coupon, data) = fake_coupon_data(['electronics', 'beauty', 'smartphones', 'clothes'])
    print(data)
    if coupon not in coupons:
        coupons[coupon] = 1
        endpoint("coupon/createCoupon",data)
    else:
        print("coupon alredy present")
# Out:
# {'couponcode': {'coupon': 'O28J9V', 'maxdiscount': 30, 'categories': ['smartphones', 'beauty'], 'minprice': 661, 'maxprice': 9066}}
# Data added successfully!
# {'couponcode': {'coupon': '3JD2CZ', 'maxdiscount': 21, 'categories': ['electronics', 'smartphones', 'beauty', 'clothes'], 'minprice': 1166, 'maxprice': 6771}}
# Data added successfully!
# {'couponcode': {'coupon': 'ET3LWG', 'maxdiscount': 49, 'categories': ['electronics'], 'minprice': 1496, 'maxprice': 4090}}
# Data added successfully!
# {'couponcode': {'coupon': 'JCVBVF', 'maxdiscount': 35, 'categories': ['beauty', 'clothes', 'electronics', 'smartphones'], 'minprice': 1259, 'maxprice': 8342}}
# Data added successfully!
# {'couponcode': {'coupon': '7HV2HQ', 'maxdiscount': 28, 'categories': ['electronics', 'smartphones', 'clothes', 'beauty'], 'minprice': 1238, 'maxprice': 3632}}
# Data added successfully!
# {'couponcode': {'coupon': 'ZGSFO0', 'maxdiscount': 25, 'categories': ['clothes'], 'minprice': 1431, 'maxprice': 4099}}
# ...

# %%
## This is a demo json file to insert data 
import random
from faker import Faker
fake = Faker()
def create_fakedata():
    petname = fake.first_name()
    petprice = int(str(random.randint(1,10))+random.choice(["999","499"]))
    petage = random.randint(1,20)
    maxage = random.randint(5,55)
    discount = random.choice([10,15,20,25,30])
    pettype = random.choice(["cat","dog","horse","alphca"])
    return 

for i in range(100):
# Out:
# Phillip

# %%
! pip install faker
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
