# %%
! pip install rembg
# Out:
# Collecting rembg
#   Downloading rembg-2.0.56-py3-none-any.whl (32 kB)
# Collecting jsonschema
#   Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#      ---------------------------------------- 85.5/85.5 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from rembg) (1.26.4)
# Collecting onnxruntime
#   Downloading onnxruntime-1.17.1-cp311-cp311-win_amd64.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 5.8 MB/s eta 0:00:00
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl (38.5 MB)
#      ---------------------------------------- 38.5/38.5 MB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from rembg) (10.2.0)
# Requirement already satisfied: pooch in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from rembg) (1.8.1)
# Collecting pymatting
#   Downloading PyMatting-1.1.12-py3-none-any.whl (52 kB)
#      ---------------------------------------- 53.0/53.0 kB 2.7 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.22.0-cp311-cp311-win_amd64.whl (24.5 MB)
#      ---------------------------------------- 24.5/24.5 MB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from rembg) (1.12.0)
# Requirement already satisfied: tqdm in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from rembg) (4.66.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from jsonschema->rembg) (23.2.0)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.34.0-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.18.0-cp311-none-win_amd64.whl (206 kB)
#      -------------------------------------- 206.7/206.7 kB 6.3 MB/s eta 0:00:00
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.0/46.0 kB ? eta 0:00:00
# Collecting flatbuffers
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: packaging in c:\users\pc\appdata\roaming\python\python311\site-packages (from onnxruntime->rembg) (23.2)
# Requirement already satisfied: protobuf in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime->rembg) (4.25.3)
# Requirement already satisfied: sympy in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime->rembg) (1.12)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from pooch->rembg) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from pooch->rembg) (2.31.0)
# Requirement already satisfied: numba!=0.49.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from pymatting->rembg) (0.59.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->rembg) (2.8.8)
# Collecting imageio>=2.27
#   Downloading imageio-2.34.0-py3-none-any.whl (313 kB)
#      -------------------------------------- 313.4/313.4 kB 9.8 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
#      -------------------------------------- 224.5/224.5 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->rembg) (0.3)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python311\site-packages (from tqdm->rembg) (0.4.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from numba!=0.49.0->pymatting->rembg) (0.42.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch->rembg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch->rembg) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2022.12.7)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime->rembg) (1.3.0)
# Collecting pyreadline3
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: pyreadline3, flatbuffers, tifffile, rpds-py, opencv-python-headless, imageio, humanfriendly, scikit-image, referencing, pymatting, coloredlogs, onnxruntime, jsonschema-specifications, jsonschema, rembg
# Successfully installed coloredlogs-15.0.1 flatbuffers-24.3.25 humanfriendly-10.0 imageio-2.34.0 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 onnxruntime-1.17.1 opencv-python-headless-4.9.0.80 pymatting-1.1.12 pyreadline3-3.4.1 referencing-0.34.0 rembg-2.0.56 rpds-py-0.18.0 scikit-image-0.22.0 tifffile-2024.2.12
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import rembg
import numpy as np
from PIL import Image

# Load the input image
input_image = Image.open('C:/Users/pc/Downloads/ecommerce/ecommerce/frontend/src/static/images/logo.png')

# Convert the input image to a numpy array
input_array = np.array(input_image)

# Apply background removal using rembg
output_array = rembg.remove(input_array)

# Create a PIL Image from the output array
output_image = Image.fromarray(output_array)

# Save the output image
output_image.save('logo.png')

# %%
yashwant = 0
for i in range(1,100):
    yashwant += i 
    print(yashwant)

print(yashwant)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950
# 4950
